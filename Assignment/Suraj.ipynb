# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
import seaborn as sns

# %%
link="https://raw.githubusercontent.com/kb22/Heart-Disease-Prediction/refs/heads/master/dataset.csv"
df=pd.read_csv(link)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape #total number of row and column
# Out:
# (303, 14)

# %%
df['target'].unique()
# Out:
# array([1, 0])

# %%
df.isna()
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# ..     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 298  False  False  False     False  False  False    False    False  False
# 299  False  False  False     False  False  False    False    False  False
# 300  False  False  False     False  False  False    False    False  False
# 301  False  False  False     False  False  False    False    False  False
# 302  False  False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# 0      False  False  False  False   False
# 1      False  False  False  False   False
# 2      False  False  False  False   False
# 3      False  False  False  False   False
# 4      False  False  False  False   False
# ..       ...    ...    ...    ...     ...
# 298    False  False  False  False   False
# 299    False  False  False  False   False
# 300    False  False  False  False   False
# 301    False  False  False  False   False
# 302    False  False  False  False   False
#
# [303 rows x 14 columns]

# %%
features=df.drop(['target',], axis=1)
target=df['target']

X=features.values
y=target.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
y_train = pd.Series(y_train)
y_test = pd.Series(y_test)

# %%
# Normalize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train=torch.tensor(X_train, dtype=torch.float32)
X_test=torch.tensor(X_test, dtype=torch.float32)

y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)  # Convert to float32 and reshape to (N, 1)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %%
class SimpleBinaryClassifier(nn.Module):
    def __init__(self):
        super(SimpleBinaryClassifier, self).__init__()
        self.linear = nn.Linear(13, 1)  # 13 input features, 1 output for binary classification

    def forward(self, x):
        return self.linear(x)

# %%
model = SimpleBinaryClassifier()

# Define the loss function and optimizer
loss_function = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.04)

# Training loop
epochs = 100
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()  # Clear previous gradients
    logits = model(X_train)  # Forward pass

    # Double-check data types
    print(f"logits dtype: {logits.dtype}, y_train dtype: {y_train.dtype}")

    loss = loss_function(logits, y_train)  # Compute loss
    loss.backward()  # Backward pass
    optimizer.step()  # Update weights

    print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}")
# Out:
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 1/100, Loss: 0.7366
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 2/100, Loss: 0.6629
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 3/100, Loss: 0.6014
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 4/100, Loss: 0.5515
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 5/100, Loss: 0.5118
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 6/100, Loss: 0.4806
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 7/100, Loss: 0.4562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 8/100, Loss: 0.4372
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 9/100, Loss: 0.4223
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 10/100, Loss: 0.4106
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 11/100, Loss: 0.4014
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 12/100, Loss: 0.3943
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 13/100, Loss: 0.3887
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 14/100, Loss: 0.3844
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 15/100, Loss: 0.3811
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 16/100, Loss: 0.3785
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 17/100, Loss: 0.3766
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 18/100, Loss: 0.3751
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 19/100, Loss: 0.3740
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 20/100, Loss: 0.3731
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 21/100, Loss: 0.3723
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 22/100, Loss: 0.3716
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 23/100, Loss: 0.3709
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 24/100, Loss: 0.3702
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 25/100, Loss: 0.3695
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 26/100, Loss: 0.3688
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 27/100, Loss: 0.3680
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 28/100, Loss: 0.3672
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 29/100, Loss: 0.3664
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 30/100, Loss: 0.3655
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 31/100, Loss: 0.3647
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 32/100, Loss: 0.3639
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 33/100, Loss: 0.3631
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 34/100, Loss: 0.3624
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 35/100, Loss: 0.3618
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 36/100, Loss: 0.3612
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 37/100, Loss: 0.3607
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 38/100, Loss: 0.3602
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 39/100, Loss: 0.3598
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 40/100, Loss: 0.3594
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 41/100, Loss: 0.3591
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 42/100, Loss: 0.3588
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 43/100, Loss: 0.3586
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 44/100, Loss: 0.3584
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 45/100, Loss: 0.3582
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 46/100, Loss: 0.3580
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 47/100, Loss: 0.3578
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 48/100, Loss: 0.3577
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 49/100, Loss: 0.3576
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 50/100, Loss: 0.3575
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 51/100, Loss: 0.3574
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 52/100, Loss: 0.3573
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 53/100, Loss: 0.3572
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 54/100, Loss: 0.3572
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 55/100, Loss: 0.3571
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 56/100, Loss: 0.3570
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 57/100, Loss: 0.3570
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 58/100, Loss: 0.3569
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 59/100, Loss: 0.3568
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 60/100, Loss: 0.3568
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 61/100, Loss: 0.3567
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 62/100, Loss: 0.3566
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 63/100, Loss: 0.3566
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 64/100, Loss: 0.3565
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 65/100, Loss: 0.3565
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 66/100, Loss: 0.3565
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 67/100, Loss: 0.3564
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 68/100, Loss: 0.3564
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 69/100, Loss: 0.3564
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 70/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 71/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 72/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 73/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 74/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 75/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 76/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 77/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 78/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 79/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 80/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 81/100, Loss: 0.3563
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 82/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 83/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 84/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 85/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 86/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 87/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 88/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 89/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 90/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 91/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 92/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 93/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 94/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 95/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 96/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 97/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 98/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 99/100, Loss: 0.3562
# logits dtype: torch.float32, y_train dtype: torch.float32
# Epoch 100/100, Loss: 0.3562

# %%
with torch.no_grad():
    model.eval()
    test_logits = model(X_test)
    predictions = torch.sigmoid(test_logits) >= 0.5
    predicted_labels = (predictions > 0.5).float()
    accuracy = (predictions == y_test).sum().item() / y_test.size(0)
    print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 86.84%

# %%
print("Actual vs Predicted Targets:")
for actual, predicted in zip(y_test[:10], predicted_labels[:10]):  # Print first 10 results
    print(f"Actual: {actual.item()} - Predicted: {predicted.item()}")
# Out:
# Actual vs Predicted Targets:
# Actual: 1.0 - Predicted: 1.0
# Actual: 0.0 - Predicted: 0.0
# Actual: 0.0 - Predicted: 0.0
# Actual: 0.0 - Predicted: 0.0
# Actual: 1.0 - Predicted: 1.0
# Actual: 0.0 - Predicted: 0.0
# Actual: 1.0 - Predicted: 1.0
# Actual: 1.0 - Predicted: 1.0
# Actual: 1.0 - Predicted: 1.0
# Actual: 0.0 - Predicted: 0.0
